# %%
import numpy as np
import pandas as pd
from scipy import io
from src.helper_functions import load_data, get_model_perfs, init_model_perfs,\
                                 save_model, save_model_perfs, check_is_best,\
                                 read_model, evaluate_model_predictions,\
                                 update_model_perfs, check_and_save,\
                                 adjusted_classes

# %%
x_tr, y_tr, x_te, y_te = load_data()
for target in y_tr.columns:
    print(target)
    display(get_model_perfs(target))
# Out:
# NR.AhR
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.911475   0.756757  0.383562  0.509091  0.905028
# 1   RF_modT   0.235000  0.842623   0.424837  0.890411  0.575221  0.905028
# 2   RF_modT   0.370000  0.903279   0.597222  0.589041  0.593103  0.904939
# 3       DNN   0.500000  0.806557   0.352941  0.739726  0.477876  0.864200
# 4  DNN_modT   0.714105  0.873770   0.479167  0.630137  0.544379  0.864200
#
#    avg_precision       confusion_matrix   model_filename
# 0       0.602102   [[528, 9], [45, 28]]       RF0.joblib
# 1       0.602102   [[449, 88], [8, 65]]  RF_modT0.joblib
# 2       0.599707  [[508, 29], [30, 43]]  RF_modT1.joblib
# 3       0.521595  [[438, 99], [19, 54]]          DNN0.h5
# 4       0.521595  [[487, 50], [27, 46]]     DNN_modT0.h5
# NR.AR
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.981229   0.666667  0.166667  0.266667  0.687573
# 1   RF_modT   0.140000  0.965870   0.277778  0.416667  0.333333  0.687573
# 2       DNN   0.500000  0.733788   0.044304  0.583333  0.082353  0.687064
# 3  DNN_modT   0.862187  0.914676   0.104167  0.416667  0.166667  0.687064
#
#    avg_precision      confusion_matrix   model_filename
# 0       0.274786   [[573, 1], [10, 2]]       RF0.joblib
# 1       0.274786   [[561, 13], [7, 5]]  RF_modT0.joblib
# 2       0.062362  [[423, 151], [5, 7]]          DNN0.h5
# 3       0.062362   [[531, 43], [7, 5]]     DNN_modT0.h5
# NR.AR.LBD
#       model  threshold  accuracy  precision  recall        f1   auc_roc  \
# 0        RF   0.500000  0.984536   0.000000   0.000  0.000000  0.708515
# 1   RF_modT   0.240000  0.977663   0.142857   0.125  0.133333  0.708515
# 2       DNN   0.500000  0.742268   0.026667   0.500  0.050633  0.704486
# 3  DNN_modT   0.922771  0.963918   0.066667   0.125  0.086957  0.704486
#
#    avg_precision      confusion_matrix   model_filename
# 0       0.049861    [[573, 1], [8, 0]]       RF0.joblib
# 1       0.049861    [[568, 6], [7, 1]]  RF_modT0.joblib
# 2       0.032759  [[428, 146], [4, 4]]          DNN0.h5
# 3       0.032759   [[560, 14], [7, 1]]     DNN_modT0.h5
# NR.Aromatase
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.929924   1.000000  0.051282  0.097561  0.754077
# 1   RF_modT   0.125000  0.840909   0.258065  0.615385  0.363636  0.754077
# 2       DNN   0.500000  0.774621   0.172131  0.538462  0.260870  0.739342
# 3  DNN_modT   0.549256  0.791667   0.180180  0.512821  0.266667  0.739342
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.298764     [[489, 0], [37, 2]]       RF0.joblib
# 1       0.298764   [[420, 69], [15, 24]]  RF_modT0.joblib
# 2       0.162246  [[388, 101], [18, 21]]          DNN0.h5
# 3       0.162246   [[398, 91], [19, 20]]     DNN_modT0.h5
# NR.ER
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.916667   0.750000  0.235294  0.358209  0.792073
# 1   RF_modT   0.320000  0.905039   0.523810  0.431373  0.473118  0.792073
# 2       DNN   0.500000  0.738372   0.195652  0.529412  0.285714  0.703247
# 3  DNN_modT   0.781725  0.844961   0.306667  0.450980  0.365079  0.703247
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.457295    [[461, 4], [39, 12]]       RF0.joblib
# 1       0.457295   [[445, 20], [29, 22]]  RF_modT0.joblib
# 2       0.223835  [[354, 111], [24, 27]]          DNN0.h5
# 3       0.223835   [[413, 52], [28, 23]]     DNN_modT0.h5
# NR.ER.LBD
#       model  threshold  accuracy  precision  recall        f1   auc_roc  \
# 0        RF   0.500000  0.968333   0.600000    0.15  0.240000  0.769957
# 1   RF_modT   0.280000  0.965000   0.461538    0.30  0.363636  0.769957
# 2       DNN   0.500000  0.726667   0.050000    0.40  0.088889  0.655776
# 3  DNN_modT   0.746507  0.840000   0.077778    0.35  0.127273  0.655776
#
#    avg_precision       confusion_matrix   model_filename
# 0       0.287579    [[578, 2], [17, 3]]       RF0.joblib
# 1       0.287579    [[573, 7], [14, 6]]  RF_modT0.joblib
# 2       0.056222  [[428, 152], [12, 8]]          DNN0.h5
# 3       0.056222   [[497, 83], [13, 7]]     DNN_modT0.h5
# NR.PPAR.gamma
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.947107   0.000000  0.000000  0.000000  0.762645
# 1   RF_modT   0.070000  0.791736   0.137405  0.580645  0.222222  0.762645
# 2       DNN   0.500000  0.730579   0.092593  0.483871  0.155440  0.679752
# 3  DNN_modT   0.484808  0.664463   0.098131  0.677419  0.171429  0.679752
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.155184     [[573, 1], [31, 0]]       RF0.joblib
# 1       0.155184  [[461, 113], [13, 18]]  RF_modT0.joblib
# 2       0.092547  [[427, 147], [16, 15]]          DNN0.h5
# 3       0.092547  [[381, 193], [10, 21]]     DNN_modT0.h5
# SR.ARE
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.830631   0.480000  0.129032  0.203390  0.777871
# 1   RF_modT   0.333333  0.809009   0.442478  0.537634  0.485437  0.777871
# 2       DNN   0.500000  0.763964   0.362319  0.537634  0.432900  0.719709
# 3  DNN_modT   0.520910  0.769369   0.370370  0.537634  0.438596  0.719709
#
#    avg_precision       confusion_matrix   model_filename
# 0       0.418806  [[449, 13], [81, 12]]       RF0.joblib
# 1       0.418806  [[399, 63], [43, 50]]  RF_modT0.joblib
# 2       0.401992  [[374, 88], [43, 50]]          DNN0.h5
# 3       0.401992  [[377, 85], [43, 50]]     DNN_modT0.h5
# SR.ATAD5
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.938907   0.000000  0.000000  0.000000  0.809188
# 1   RF_modT   0.210000  0.943730   0.555556  0.394737  0.461538  0.809188
# 2       DNN   0.500000  0.739550   0.130952  0.578947  0.213592  0.716024
# 3  DNN_modT   0.840163  0.898714   0.272727  0.394737  0.322581  0.716024
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.409218     [[584, 0], [38, 0]]       RF0.joblib
# 1       0.409218   [[572, 12], [23, 15]]  RF_modT0.joblib
# 2       0.175477  [[438, 146], [16, 22]]          DNN0.h5
# 3       0.175477   [[544, 40], [23, 15]]     DNN_modT0.h5
# SR.HSE
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.965574   0.600000  0.136364  0.222222  0.752512
# 1   RF_modT   0.260000  0.945902   0.322581  0.454545  0.377358  0.752512
# 2       DNN   0.500000  0.736066   0.073620  0.545455  0.129730  0.669179
# 3  DNN_modT   0.940785  0.963934   0.500000  0.090909  0.153846  0.669179
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.245287     [[586, 2], [19, 3]]       RF0.joblib
# 1       0.245287   [[567, 21], [12, 10]]  RF_modT0.joblib
# 2       0.096227  [[437, 151], [10, 12]]          DNN0.h5
# 3       0.096227     [[586, 2], [20, 2]]     DNN_modT0.h5
# SR.MMP
#       model  threshold  accuracy  precision  recall        f1   auc_roc  \
# 0        RF    0.50000  0.909761   0.677419    0.35  0.461538  0.923982
# 1   RF_modT    0.28000  0.883978   0.486486    0.90  0.631579  0.923982
# 2       DNN    0.50000  0.830571   0.368852    0.75  0.494505  0.847326
# 3  DNN_modT    0.52091  0.836096   0.378151    0.75  0.502793  0.847326
#
#    avg_precision       confusion_matrix   model_filename
# 0       0.544850  [[473, 10], [39, 21]]       RF0.joblib
# 1       0.544850   [[426, 57], [6, 54]]  RF_modT0.joblib
# 2       0.402595  [[406, 77], [15, 45]]          DNN0.h5
# 3       0.402595  [[409, 74], [15, 45]]     DNN_modT0.h5
# SR.p53
#       model  threshold  accuracy  precision    recall        f1   auc_roc  \
# 0        RF   0.500000  0.935065   0.666667  0.048780  0.090909  0.787402
# 1   RF_modT   0.260000  0.899351   0.266667  0.292683  0.279070  0.787402
# 2       DNN   0.500000  0.745130   0.137500  0.536585  0.218905  0.727762
# 3  DNN_modT   0.493382  0.709416   0.144330  0.682927  0.238298  0.727762
#
#    avg_precision        confusion_matrix   model_filename
# 0       0.211803     [[574, 1], [39, 2]]       RF0.joblib
# 1       0.211803   [[542, 33], [29, 12]]  RF_modT0.joblib
# 2       0.135206  [[437, 138], [19, 22]]          DNN0.h5
# 3       0.135206  [[409, 166], [13, 28]]     DNN_modT0.h5

# %%
y_tr.columns
# Out:
# Index(['NR.AhR', 'NR.AR', 'NR.AR.LBD', 'NR.Aromatase', 'NR.ER', 'NR.ER.LBD',
#        'NR.PPAR.gamma', 'SR.ARE', 'SR.ATAD5', 'SR.HSE', 'SR.MMP', 'SR.p53'],
#       dtype='object')
